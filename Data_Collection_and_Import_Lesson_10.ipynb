# %% [markdown]
# <a href="https://colab.research.google.com/github/JJean-B/HU-Python-Data-Bootcamp-2025/blob/main/Data_Collection_and_Import_Lesson_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The goal with this practice assignment is to understand the initial code needed to import data from your data source.
#
# ## Mount your Google Drive
# Begin with mounting your Google Drive. 1. Click the folder icon to the left.
# 2. Click the grey folder with the Google Drive triangle logo.
# 3. This will add a block of code to your notebook.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)
# ```
# I add the `force_remount=True` boolean statement to ensure each time I run the block I have a stable connection to the Google Drive interface.
#
# 4. Run the code cell. This will generate a popup window that asks the user to authorize Google Drive connection to Google Colab. Once all of the permissions are active this should return the statement ```Mounted at /content/drive```

# %%
#DIY
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# ## Import your initial libraries.
# The initial libraries used in all data science applications are NumPy, Pandas, Matplotlib, and Seaborn. Import the libraries in the code block below.
#
# * Recall that matplotlib is installed as `matplotlib.pyplot`.
# * Use the alias np for NumPy.
# * Use the alias pd for Pandas.
# * Use the alias plt for Matplotlib.
# Use the alias sns for Seaborn.

# %%
#DIY
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading some data
# Now that the libraries are loaded it is time to load some data. You have mounted your Google Drive which allows you to seamlessly load data stored on your Google Drive.
#
# 1. Click the folder icon to the left to open the files menu.
# 2. click the arrow beside `drive` to view the contents.
# 3. Click the arrow beside `My Drive` to view the contents.
# 4. Click the arrow beside `Colab Notebooks` to view the contents.
# 5. Select the filename you wish to load. Click the vertical three dots that appears as you hover over your file.
# 6. Select `Copy path`.
# 7. Create a variable called `path` and assign the value as the copied link. Be sure the value is enclosed in quotes.
# 8. Create a new variable that will be a unique identifier for your data stored in the variable. Using the Syntax below, assign the data in the `path` variable to the new variable.
# ```
# uniqueVariable = pd.read_csv(path)
# ```
# 9. To view the first five rows of the data we use the `dataFrameName.head()` where you can leave the parentheses empty for just the first five rows or add a number in the parentheses to view that number of rows. Try viewing the first eight rows of data.

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Copy of Affordable_Rental_Housing_Developments.csv"
new_file = pd.read_csv(path)
new_file
# Out:
#     Community Area Name  Community Area Number Property Type  \
# 0        Belmont Cragin                     19        Senior
# 1    East Garfield Park                     27   Multifamily
# 2    East Garfield Park                     27   Multifamily
# 3               Oakland                     36   Multifamily
# 4         Humboldt Park                     23   Multifamily
# ..                  ...                    ...           ...
# 506            Woodlawn                     42   Multifamily
# 507          West Ridge                      2           ARO
# 508             Oakland                     36   Multifamily
# 509     Lower West Side                     31           ARO
# 510     Grand Boulevard                     38   Multifamily
#
#                        Property Name                 Address  Zip Code  \
# 0                Belmont Place Apts.    4645 W. Belmont Ave.     60641
# 1           East Garfield Park Place      3441 W. Monroe St.     60624
# 2    Homan Square Apartments Phase I       750 S. Homan Ave.     60624
# 3           Drexel Street Properties         848 E. 40th St.     60653
# 4               Nelson Mandela Apts.  3118 W. Franklin Blvd.     60624
# ..                               ...                     ...       ...
# 506                65th Street Apts.         817 E. 64th St.     60637
# 507          5822 North Western, LLC    5822 N. Western Ave.     60659
# 508               Lakefront Phase II      1120 E. Bowen Ave.     60653
# 509                   Woodwork Lofts     1414-48 W. 21st St.     60608
# 510                Cornerstone Apts.         633 E. 50th St.     60615
#
#      Phone Number            Management Company  Units  X Coordinate  \
# 0    773-427-1400    Perlmark Realty Management  110.0   1144792.615
# 1             NaN                           NaN   25.0           NaN
# 2    773-722-7320         Realty & Mortgage Co.   50.0   1153790.485
# 3    312-842-5500          East Lake Management   61.0   1182895.852
# 4    773-227-6332              Bickerdike Apts.    6.0   1155403.532
# ..            ...                           ...    ...           ...
# 506  773-684-2056  Urban Property Advisors, LLC    6.0   1182886.226
# 507  773-572-2755     Chicago Apartment Finders    2.0   1159227.225
# 508  773-548-8795  Urban Property Advisors, LLC    6.0   1184352.470
# 509  312-576-7392      Stellar Performance Inc.   10.0   1167176.941
# 510  312-577-5555   The Community Builders Inc.    7.0   1181425.624
#
#      Y Coordinate   Latitude  Longitude  \
# 0     1920829.074  41.938767 -87.743263
# 1             NaN        NaN        NaN
# 2     1896268.991  41.871197 -87.710848
# 3     1878499.666  41.821808 -87.604546
# 4     1903205.531  41.890199 -87.704740
# ..            ...        ...        ...
# 506   1862714.794  41.778493 -87.605072
# 507   1938700.509  41.987522 -87.689719
# 508   1877438.040  41.818861 -87.599236
# 509   1890229.839  41.854348 -87.661875
# 510   1871964.801  41.803910 -87.610142
#
#                                     Location
# 0                                        NaN
# 1                                        NaN
# 2      (41.8711971734122, -87.7108484249133)
# 3    (41.82180819274104, -87.60454649932994)
# 4      (41.8901994819175, -87.7047397753891)
# ..                                       ...
# 506    (41.7784934339328, -87.6050724236176)
# 507    (41.9875222634019, -87.6897187054826)
# 508    (41.8188609892833, -87.5992361922266)
# 509    (41.8543483215561, -87.6618752555649)
# 510    (41.8039101011155, -87.6101417642929)
#
# [511 rows x 14 columns]

# %%
new_file.head(8)
# Out:
#   Community Area Name  Community Area Number Property Type  \
# 0      Belmont Cragin                     19        Senior
# 1  East Garfield Park                     27   Multifamily
# 2  East Garfield Park                     27   Multifamily
# 3             Oakland                     36   Multifamily
# 4       Humboldt Park                     23   Multifamily
# 5     Grand Boulevard                     38        Senior
# 6           West Town                     24   Multifamily
# 7        Norwood Park                     10        Senior
#
#                      Property Name                 Address  Zip Code  \
# 0              Belmont Place Apts.    4645 W. Belmont Ave.     60641
# 1         East Garfield Park Place      3441 W. Monroe St.     60624
# 2  Homan Square Apartments Phase I       750 S. Homan Ave.     60624
# 3         Drexel Street Properties         848 E. 40th St.     60653
# 4             Nelson Mandela Apts.  3118 W. Franklin Blvd.     60624
# 5         Bronzeville Senior Apts.         460 E. 41st St.     60653
# 6    North and Talman Family Apts.      2654 W. North Ave.     60647
# 7    Senior Suites of Norwood Park     5700 N. Harlem Ave.     60631
#
#    Phone Number                Management Company  Units  X Coordinate  \
# 0  773-427-1400        Perlmark Realty Management  110.0   1144792.615
# 1           NaN                               NaN   25.0           NaN
# 2  773-722-7320             Realty & Mortgage Co.   50.0   1153790.485
# 3  312-842-5500              East Lake Management   61.0   1182895.852
# 4  773-227-6332                  Bickerdike Apts.    6.0   1155403.532
# 5  773-924-2100  Peoples Co-Op Management Service   97.0   1180219.199
# 6  773-486-7410       Hispanic Housing Dev. Corp.   30.0   1158184.401
# 7  888-339-2315                  Senior Lifestyle   84.0   1127328.815
#
#    Y Coordinate   Latitude  Longitude                                 Location
# 0   1920829.074  41.938767 -87.743263                                      NaN
# 1           NaN        NaN        NaN                                      NaN
# 2   1896268.991  41.871197 -87.710848    (41.8711971734122, -87.7108484249133)
# 3   1878499.666  41.821808 -87.604546  (41.82180819274104, -87.60454649932994)
# 4   1903205.531  41.890199 -87.704740    (41.8901994819175, -87.7047397753891)
# 5   1877957.214  41.820382 -87.614382    (41.8203815434508, -87.6143824353862)
# 6   1910570.961  41.910354 -87.694326    (41.9103544922391, -87.6943256396865)
# 7   1937441.873  41.984666 -87.807073    (41.9846662832426, -87.8070730078682)

# %% [markdown]
# Keep practicing with more datasets. You can use the sample datasets that come preloaded with Colab.
